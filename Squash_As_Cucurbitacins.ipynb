# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
dataI = {'As_Concentration': [50, 50, 50, 100, 100, 100, 200, 200, 200], 'Cucurbitacin_I': [0, 0, 0, 17.63911319, 0, 7.925370398, 22.67859991, 25.4854372, 15.29926491]}
dfI = pd.DataFrame(dataI)
sns.regplot(x="As_Concentration", y="Cucurbitacin_I", data=dfI)
# Out:
# <Axes: xlabel='As_Concentration', ylabel='Cucurbitacin_I'>

# %%
dataB = {'As_Concentration': [50, 50, 50, 100, 100, 100, 200, 200, 200], 'Cucurbitacin_B': [0, 0, 0, 16.370255, 0, 9.450322328, 24.73259793, 21.68809907, 17.21975289] }
dfB = pd.DataFrame(dataB)
sns.regplot(x="As_Concentration", y="Cucurbitacin_B", data=dfB)
# Out:
# <Axes: xlabel='As_Concentration', ylabel='Cucurbitacin_B'>

# %%
dataE = {'As_Concentration': [50, 50, 50, 100, 100, 100, 200, 200, 200], 'Cucurbitacin_E': [20.47059881, 11.01725448, 9.064906254, 52.36035594, 15.87304066, 26.37012705, 82.3672491, 67.20871856, 55.29471572] }
dfE = pd.DataFrame(dataE)
sns.regplot(x="As_Concentration", y="Cucurbitacin_E", data=dfE)
# Out:
# <Axes: xlabel='As_Concentration', ylabel='Cucurbitacin_E'>
